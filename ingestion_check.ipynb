# %%
import os
import pandas as pd

# %%
path = os.path.join(os.getenv("PROCESSED_DIR","./data/processed"), "tables", "labs.parquet")
df = pd.read_parquet(path)
df
# Out:
#                                  analyte  value    unit  ref_low  ref_high  \
# 0                                MH59255   28.0    None      NaN       NaN
# 1             Date Collected: 03/18/2024    3.0    None      NaN       NaN
# 2                   Iron Bind.Cap.(TIBC)  261.0    None    250.0     450.0
# 3                                UIBC 01  170.0    None    111.0     343.0
# 4                                Iron 01   91.0    None     38.0     169.0
# ..                                   ...    ...     ...      ...       ...
# 407                      Protein - Total    6.4    g/dL      NaN       NaN
# 408                     Globulin - Total    2.2    g/dL      NaN       NaN
# 409                                 MCHC   32.8    g/dL      NaN       NaN
# 410                              Albumin    4.2    g/dL      NaN       NaN
# 411  Sex Hormone Binding Globulin - Male   25.0  nmol/L      NaN       NaN
#
#      flag        date  page     vendor                            source  \
# 0    None  2024-03-18     1    LabCorp    data/labs/LabCorp_20240318.pdf
# 1    None  2024-03-18     1    LabCorp    data/labs/LabCorp_20240318.pdf
# 2    None  2024-03-18     1    LabCorp    data/labs/LabCorp_20240318.pdf
# 3    None  2024-03-18     1    LabCorp    data/labs/LabCorp_20240318.pdf
# 4    None  2024-03-18     1    LabCorp    data/labs/LabCorp_20240318.pdf
# ..    ...         ...   ...        ...                               ...
# 407  None  2023-12-07    21  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 408  None  2023-12-07    21  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 409  None  2023-12-07    22  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 410  None  2023-12-07    22  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 411  None  2023-12-07    22  Ways2Well  data/labs/Ways2Well_20231207.pdf
#
#     source_type
# 0          labs
# 1          labs
# 2          labs
# 3          labs
# 4          labs
# ..          ...
# 407        labs
# 408        labs
# 409        labs
# 410        labs
# 411        labs
#
# [412 rows x 11 columns]

# %%
df[df['vendor'] == 'Ways2Well']
# Out:
#                                  analyte  value    unit  ref_low  ref_high  \
# 389                        Basophils - %    1.1       %      NaN       NaN
# 390                                  ALT   34.0    IU/L      NaN       NaN
# 391             Testosterone Free - Male  261.1   pg/mL      NaN       NaN
# 392                    Hematocrit - Male   52.5       %      NaN       NaN
# 393                      Eosinophils - %    5.2       %      NaN       NaN
# 394                            T3 - Free    4.4   pg/mL      NaN       NaN
# 395                      Lymphocytes - %   35.2       %      NaN       NaN
# 396                           Creatinine    1.2   mg/dL      NaN       NaN
# 397                                  AST   33.0    IU/L      NaN       NaN
# 398                                  MCV   94.6      fL      NaN       NaN
# 399                                  BUN   21.0   mg/dL      NaN       NaN
# 400                        Monocytes - %    9.6       %      NaN       NaN
# 401                     Glucose: Fasting   96.0   mg/dL      NaN       NaN
# 402                                  MPV    9.2      fL      NaN       NaN
# 403                        Triglycerides  112.0   mg/dL      NaN       NaN
# 404                        DHEA-S - Male  343.0    g/dL      NaN       NaN
# 405                      HDL Cholesterol   51.0   mg/dL      NaN       NaN
# 406                      Neutrophils - %   48.9       %      NaN       NaN
# 407                      Protein - Total    6.4    g/dL      NaN       NaN
# 408                     Globulin - Total    2.2    g/dL      NaN       NaN
# 409                                 MCHC   32.8    g/dL      NaN       NaN
# 410                              Albumin    4.2    g/dL      NaN       NaN
# 411  Sex Hormone Binding Globulin - Male   25.0  nmol/L      NaN       NaN
#
#      flag        date  page     vendor                            source  \
# 389  None  2023-12-07    17  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 390  None  2023-12-07    17  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 391  None  2023-12-07    18  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 392  None  2023-12-07    18  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 393  None  2023-12-07    18  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 394  None  2023-12-07    18  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 395  None  2023-12-07    18  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 396  None  2023-12-07    19  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 397  None  2023-12-07    19  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 398  None  2023-12-07    19  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 399  None  2023-12-07    19  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 400  None  2023-12-07    20  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 401  None  2023-12-07    20  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 402  None  2023-12-07    20  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 403  None  2023-12-07    20  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 404  None  2023-12-07    21  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 405  None  2023-12-07    21  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 406  None  2023-12-07    21  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 407  None  2023-12-07    21  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 408  None  2023-12-07    21  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 409  None  2023-12-07    22  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 410  None  2023-12-07    22  Ways2Well  data/labs/Ways2Well_20231207.pdf
# 411  None  2023-12-07    22  Ways2Well  data/labs/Ways2Well_20231207.pdf
#
#     source_type
# 389        labs
# 390        labs
# 391        labs
# 392        labs
# 393        labs
# 394        labs
# 395        labs
# 396        labs
# 397        labs
# 398        labs
# 399        labs
# 400        labs
# 401        labs
# 402        labs
# 403        labs
# 404        labs
# 405        labs
# 406        labs
# 407        labs
# 408        labs
# 409        labs
# 410        labs
# 411        labs

# %%
df[df['vendor'] == 'ways2well'].shape
# Out:
# (0, 11)

# %%
df[df['vendor'] == 'LabCorp']
# Out:
#                             analyte       value  unit  ref_low  ref_high  \
# 0                           MH59255        28.0  None      NaN       NaN
# 1        Date Collected: 03/18/2024         3.0  None      NaN       NaN
# 2              Iron Bind.Cap.(TIBC)       261.0  None    250.0     450.0
# 3                           UIBC 01       170.0  None    111.0     343.0
# 4                           Iron 01        91.0  None     38.0     169.0
# ..                              ...         ...   ...      ...       ...
# 384  Triiodothyronine (T3), Free 01         3.1  None      2.0       4.4
# 385             Apolipoprotein B 03        62.0  None      NaN      90.0
# 386                    425-417-3604       877.0  None      NaN       NaN
# 387                      05/26/1995  21025370.0  None      NaN       NaN
# 388              Reference Interval        13.0     %     13.0      17.7
#
#      flag        date  page   vendor                          source  \
# 0    None  2024-03-18     1  LabCorp  data/labs/LabCorp_20240318.pdf
# 1    None  2024-03-18     1  LabCorp  data/labs/LabCorp_20240318.pdf
# 2    None  2024-03-18     1  LabCorp  data/labs/LabCorp_20240318.pdf
# 3    None  2024-03-18     1  LabCorp  data/labs/LabCorp_20240318.pdf
# 4    None  2024-03-18     1  LabCorp  data/labs/LabCorp_20240318.pdf
# ..    ...         ...   ...      ...                             ...
# 384  None  2025-03-27     4  LabCorp  data/labs/LabCorp_20250327.pdf
# 385  None  2025-03-27     4  LabCorp  data/labs/LabCorp_20250327.pdf
# 386  None  2025-03-27     4  LabCorp  data/labs/LabCorp_20250327.pdf
# 387  None  2025-03-27     4  LabCorp  data/labs/LabCorp_20250327.pdf
# 388  None  2025-03-27     5  LabCorp  data/labs/LabCorp_20250327.pdf
#
#     source_type
# 0          labs
# 1          labs
# 2          labs
# 3          labs
# 4          labs
# ..          ...
# 384        labs
# 385        labs
# 386        labs
# 387        labs
# 388        labs
#
# [389 rows x 11 columns]
